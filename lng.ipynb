# %%
import pandas as pd
from openpyxl import load_workbook

workbook = load_workbook('lng-export.xlsx')

sheets = workbook.sheetnames[1:12]
print(sheets)
# workbook.sheetnames

# df = pd.read_excel('lng-export.xlsx')
# df.sheet_names
# Out:
# ['LNG Exports - Sabine', 'LNG Exports - Cove Point', 'LNG Exports - Corpus Christi', 'LNG Exports - Cameron', 'LNG Exports - Freeport', 'LNG Exports - Elba Island', 'LNG Exports - Venture Global', 'LNG Exports - ISO, American', 'LNG Exports - ISO, Eagle', 'LNG Exports - ISO, MKVH', 'LNG Exports - ISO, Carib']

# %%
df = pd.read_excel('lng-export.xlsx', sheet_name=sheets[0])
df.head(10)
# Out:
#        Office of Fossil Energy and Carbon Management  \
# 0                  Office of Resource Sustainability
# 1     Office of Regulation, Analysis, and Engagement
# 2                 Division of Natural Gas Regulation
# 3                               Phone:  202-586-7991
# 4                       Email:  ngreports@hq.doe.gov
# 5                                                NaN
# 6  VESSEL-BORNE EXPORTS OF DOMESTICALLY-PRODUCED ...
# 7                                                NaN
# 8                                  Date of Departure
# 9                                2022-01-01 00:00:00
#
#                       Unnamed: 1                     Unnamed: 2  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# ...
